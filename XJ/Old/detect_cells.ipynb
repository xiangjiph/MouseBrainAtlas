# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import sys, os

sys.path.append(os.path.join(os.environ['REPO_DIR'], 'utilities'))
sys.path.append(os.path.join(os.environ['REPO_DIR'], 'cells'))
# sys.path.append(os.path.join(os.environ['REPO_DIR'], 'annotation'))
# sys.path.append(os.path.join(os.environ['REPO_DIR'], 'learning'))

import numpy as np
from skimage.measure import regionprops
from skimage.filters import threshold_otsu
from scipy.ndimage.morphology import distance_transform_edt
from skimage.feature import peak_local_max
from skimage.morphology import watershed
from skimage.measure import regionprops, label, find_contours
from skimage.transform import resize
from skimage.color import rgb2hsv
import pandas
from annotation_utilities import *
from registration_utilities import *
from learning_utilities import *
from data_manager import *
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# No vtk
# Child returned 0
# Setting environment for AWS compute node
# rm -rf /shared/CSHL_data_processed/MD585/MD585_sorted_filenames.txt && mkdir -p /shared/CSHL_data_processed/MD585
# aws s3 cp s3://mousebrainatlas-data/CSHL_data_processed/MD585/MD585_sorted_filenames.txt /shared/CSHL_data_processed/MD585/MD585_sorted_filenames.txt
# Child returned 0
# 0.51 seconds.
# Child returned 0
# rm -rf /shared/CSHL_data_processed/MD585/MD585_anchor.txt && mkdir -p /shared/CSHL_data_processed/MD585
# aws s3 cp s3://mousebrainatlas-data/CSHL_data_processed/MD585/MD585_anchor.txt /shared/CSHL_data_processed/MD585/MD585_anchor.txt
# Child returned 0
# ...

# %%
save_folder_path = '/shared/MouseBrainAtlasXiang/XJ/Output/detect_cell_alternatives_output/'
if os.path.isdir(save_folder_path):
    sys.stderr.write('Folder already exists.')
else:
    os.makedirs(save_folder_path)
    sys.stderr.write('Folder created.')
# Out:
# /shared/MouseBrainAtlasXiang

# %%
stack = 'MD589'
metadata_cache['section_limits'][stack]
patch_size = 224
patch_half_size = patch_size / 2
stride = 56
# Crop images
# 
crop_x_min = 9000
crop_x_max = 10500
crop_y_min = 3000
crop_y_max = 4500

# Inside
# crop_x_min = 4000
# crop_x_max = 6000
# crop_y_min = 2400
# crop_y_max = 4400

# Whole
# crop_x_min = 0
# crop_y_min = 0
# _, _, crop_y_max, crop_x_max = get_default_gridspec(stack=stack, patch_size=patch_size, stride=stride)

crop_image_width = crop_y_max - crop_y_min
crop_image_height = crop_x_max - crop_x_min



def get_filename(define_list):
    """
    get_finelname(list_of_definition_component): return a string concaining filename definition, seperated by '_' 
    """
    filename_head = ''
    for filename_element in map(str,define_list):
        filename_head = filename_head + filename_element + '_'
    return filename_head

patch_center_pixel_location = grid_parameters_to_sample_locations((patch_size, stride, crop_image_width, crop_image_height ))
patch_ul = patch_center_pixel_location + ( - patch_half_size, - patch_half_size )
patch_ur = patch_center_pixel_location + ( - patch_half_size,   patch_half_size )
patch_dl = patch_center_pixel_location + (   patch_half_size, - patch_half_size )
patch_dr = patch_center_pixel_location + (   patch_half_size,   patch_half_size )
patch_contour = np.array(zip(patch_ul, patch_ur, patch_dr, patch_dl))

# Options
option_rescale_grayscale = True
option_THimage_save = True;
option_save_image_extension = '.png'

# Process images
option_label_connectivity = 4;

# %%
# Set examine section number range and download from S3 if not available
img_filename = []
secIndexList = range(200, 204)
for tempIndex1 in range(len(secIndexList)):
    img_filename.append(DataManager.get_image_filepath(stack=stack, section=secIndexList[tempIndex1], resol='lossless', version='cropped'))
    if os.path.isfile(img_filename[tempIndex1]):
        sys.stderr.write('Image files are already available. \n')
        continue
    else:
        try:
            download_from_s3(img_filename[tempIndex1])
        except:
            sys.stderr.write('Download fail. Skip this file...\n')
            continue
# Out:
# rm -rf /shared/CSHL_data_processed/MD589/MD589_lossless_alignedTo_MD589-IHC31-2015.07.30-23.26.22_MD589_1_0091_cropped/MD589-N36-2015.07.30-18.28.52_MD589_2_0107_lossless_alignedTo_MD589-IHC31-2015.07.30-23.26.22_MD589_1_0091_cropped.tif && mkdir -p /shared/CSHL_data_processed/MD589/MD589_lossless_alignedTo_MD589-IHC31-2015.07.30-23.26.22_MD589_1_0091_cropped
# aws s3 cp s3://mousebrainatlas-data/CSHL_data_processed/MD589/MD589_lossless_alignedTo_MD589-IHC31-2015.07.30-23.26.22_MD589_1_0091_cropped/MD589-N36-2015.07.30-18.28.52_MD589_2_0107_lossless_alignedTo_MD589-IHC31-2015.07.30-23.26.22_MD589_1_0091_cropped.tif /shared/CSHL_data_processed/MD589/MD589_lossless_alignedTo_MD589-IHC31-2015.07.30-23.26.22_MD589_1_0091_cropped/MD589-N36-2015.07.30-18.28.52_MD589_2_0107_lossless_alignedTo_MD589-IHC31-2015.07.30-23.26.22_MD589_1_0091_cropped.tif
# Child returned 0
# Child returned 0
# 4.12 seconds.
# Child returned 0
# ...

# %%
plt.figure(figsize=(10,10));
plt.imshow(imread(img_filename[0])[crop_x_min:crop_x_max, crop_y_min:crop_y_max]);

# %% [markdown]
# # Crop Images

# %%
# sec = 192
# img_filename = DataManager.get_image_filepath(stack=stack, section=sec, resol='lossless', version='cropped')
# download_from_s3(img_filename)
im_cropped = []
for imIndex in img_filename:
# for imIndex in [img_filename[0]]:
    im_cropped.append(img_as_ubyte(rgb2gray(imread(imIndex)[crop_x_min:crop_x_max, crop_y_min:crop_y_max])))
#     im_cropped = img_as_ubyte(rgb2gray(img_cropped))
    
im_cropped_h, im_cropped_w = im_cropped[0].shape[:2]

# %%
display_images_in_grids(im_cropped, nc = 5)

# %%
option_rescale_grayscale = True
option_inverse_color = False
secIndex = 0


if option_rescale_grayscale:
    tempImage = im_cropped[secIndex]
    vmin = np.percentile(tempImage, 0)
    vmax = np.percentile(tempImage, 100)
    tempImage = (tempImage - vmin) / (vmax - vmin)
    tempImage = np.maximum(np.minimum(tempImage, 1), 0)
    tempImage = img_as_ubyte(tempImage)
    if option_inverse_color:
        tempImage = 255 - img_as_ubyte(tempImage)
else:
    tempImage = im_cropped[secIndex]

# %%
# Grayscale threshold scan
filename_define_list = [stack, secIndexList[secIndex], crop_x_min, crop_x_max, crop_y_min, crop_y_max]
filename_head = get_filename(filename_define_list)

option_THimage_save = True;
option_save_image_extension = '.png'

# for tempTH in range(0,255,25):
for tempTH in range(200,240,5):
    plt.figure(figsize=(10,10));
    image_thresholded = tempImage > tempTH;
    plt.imshow(image_thresholded, cmap=plt.cm.gray)
    plt.title('Pixel > Threshold = {}'.format(tempTH))
    plt.colorbar()
    if option_THimage_save:
#         tempTH_filename = os.path.join(save_folder_path, str(tempTH))
        tempTH_filename = os.path.join(save_folder_path,filename_head+'Threshold_%.3d'% tempTH +option_save_image_extension)
#         print tempTH_filename
#         plt.imsave(tempTH_filename,image_thresholded)
        plt.savefig(tempTH_filename)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-b17354c65751> in <module>()
#      15     if option_THimage_save:
#      16 #         tempTH_filename = os.path.join(save_folder_path, str(tempTH))
# ---> 17         tempTH_filename = os.path.join(save_folder_path,filename_head+'Threshold_%.3d'% tempTH +option_save_image_extension)
#      18 #         print tempTH_filename
#      19 #         plt.imsave(tempTH_filename,image_thresholded)
#
# NameError: name 'save_folder_path' is not defined

# %%
# option_label_connectivity = 4;
# image_front_labeled = label(image_forground, neighbors=option_label_connectivity);
# image_back_labeled = label(image_background, neighbors=option_label_connectivity);
# image_front_measure = regionprops(image_front_labeled);
# image_back_measure = regionprops(image_back_labeled);

# %%
np.percentile(tempImage.flatten(),13.5)
# Out:
# 148.0

# %%
plt.hist(tempImage.flatten(), bins=256, normed=True);
plt.title('Normalized grayscale histrogram of cropped original image')
plt.show()

# %% [markdown]
# # Patch Analysis

# %%
# Threshold of the whole cropped image - by Otsu
from skimage.filters import threshold_otsu
otsu_thresh = threshold_otsu(tempImage)
tempImage_BW = tempImage > otsu_thresh
plt.figure(figsize=(20,20));
plt.imshow(tempImage_BW, cmap=plt.cm.gray)
plt.title('Otsu thresholded @ %d' % otsu_thresh);
plt.show();

# %%
# Get image matrix of each patch
patches = [tempImage[y - patch_half_size : y + patch_half_size, x - patch_half_size : x + patch_half_size].copy() for x, y in patch_center_pixel_location]
patch_area = patch_size ** 2

# %%
tempImage_cell_density = [np.sum(tempPatches <= otsu_thresh)/float(patch_area) for tempPatches in patches]
# for tempPatches in patches:
#     tP_BW = tempPatches <=otsu_thresh

# %%
np.count_nonzero(tempImage_cell_density)/float(len(tempImage_cell_density))
# Out:
# 0.9829867674858223

# %%
plt.hist(tempImage_cell_density,85);

# %%
tempPatches = patches[20]
tP_BW = tempPatches <= otsu_thresh
display_images_in_grids([tempPatches, tP_BW], nc=2)

# %%
# Features 
tP_features = {}
option_label_connectivity = 4;
tP_front_labeled = label(tP_BW, neighbors=option_label_connectivity);
tP_front_measure = regionprops(tP_front_labeled);
plt.imshow(tP_front_labeled);

# %%
tP_features['total_detected_density'] = np.sum(tP_BW) / float(patch_area)

# %%
tP_features
# Out:
# {'total_detected_density': 0.0}
